# %%
import pandas

# %%
employes = pandas.read_csv('employes.csv')

# %%
employes
# Out:
#                                                 photo                name  \
# 0   http://smn.com.br/content/img/equipe/michelly-...   Michelly Pheiffer
# 1   http://smn.com.br/content/img/equipe/gabriel-f...    Gabriel Ferreira
# 2   http://smn.com.br/content/img/equipe/guilherme...     Ghuilherme Maia
# 3   http://smn.com.br/content/img/equipe/daniela-r...   Daniela Rodrigues
# 4   http://smn.com.br/content/img/equipe/bruno-edu...       Bruno Eduardo
# 5   http://smn.com.br/content/img/equipe/caires-vi...        Caires Viera
# 6   http://smn.com.br/content/img/equipe/renato-ma...      Renato Marques
# 7   http://smn.com.br/content/img/equipe/claudanil...   Claudanilo Xavier
# 8   http://smn.com.br/content/img/equipe/douglas-v...    Douglas Vinicius
# 9   http://smn.com.br/content/img/equipe/felipe-ar...       Felipe Araujo
# 10  http://smn.com.br/content/img/equipe/andre-lui...          André Luiz
# 11  http://smn.com.br/content/img/equipe/yuri-alme...        Yuri Almeida
# ...

# %%
data = pandas.DataFrame(employes['role'].value_counts())
data.plot(kind='bar')
